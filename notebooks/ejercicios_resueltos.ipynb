# %%
# Ejercicio 1:  Escribe una función que reciba una cadena de texto como parámetro y devuelva un diccionario con las frecuencias
# de cada letra en la cadena. Los espacios no deben ser considerados.
 
def contar_frecuencia_letras(texto):
    """
    Recibe una cadena de texto y devuelve un diccionario
    con la frecuencia de cada letra.
    Los espacios no se tienen en cuenta.
    """
    
    frecuencias = {}
    
    for letra in texto:
        if letra != " ":
            if letra in frecuencias:
                frecuencias[letra] += 1
            else:
                frecuencias[letra] = 1
    
    return frecuencias

# %%
texto = "Hola mundo"

resultado = contar_frecuencia_letras(texto)

print(resultado)
# Out:
# {'H': 1, 'o': 2, 'l': 1, 'a': 1, 'm': 1, 'u': 1, 'n': 1, 'd': 1}

# %%
# Ejercicio 2:  Dada una lista de números, obtén una nueva lista con el doble de cada valor. Usa la función map()

def duplicar_valores(lista_numeros):
    """
    Recibe una lista de números y devuelve
    una nueva lista con el doble de cada valor.
    """
    
    resultado = list(map(lambda x: x * 2, lista_numeros))
    
    return resultado

# %%
numeros = [1, 2, 3, 4]

resultado = duplicar_valores(numeros)

print(resultado)
# Out:
# [2, 4, 6, 8]

# %%
# Ejercicio 3:  Escribe una función que tome una lista de palabras y una palabra objetivo como parámetros. La función debe
# devolver una lista con todas las palabras de la lista original que contengan la palabra objetivo.
 
def buscar_palabras(lista_palabras, palabra_objetivo):
    """
    Devuelve una lista con las palabras que contienen
    la palabra objetivo.
    """
    
    resultado = []
    
    for palabra in lista_palabras:
        if palabra_objetivo in palabra:
            resultado.append(palabra)
    
    return resultado

# %%
palabras = ["casa", "casita", "perro", "casona"]

resultado = buscar_palabras(palabras, "casa")

print(resultado)
# Out:
# ['casa']

# %%
# Ejercicio 4:  Genera una función que calcule la diferencia entre los valores de dos listas. Usa la función map()
 
def calcular_diferencia(lista1, lista2):
    """
    Calcula la diferencia entre los valores
    de dos listas usando map().
    """
    
    resultado = list(map(lambda x, y: x - y, lista1, lista2))
    
    return resultado

# %%
lista_a = [10, 20, 30]
lista_b = [1, 2, 3]

resultado = calcular_diferencia(lista_a, lista_b)

print(resultado)
# Out:
# [9, 18, 27]

# %%
# Ejercicio 5: Ecribe una función que tome una lista de números como parámetro y un valor opcional nota_aprobado, que por
# defecto es 5. La función debe calcular la media de los números en la lista y determinar si la media es mayor o igual
# que nota aprobado. Si es así, el estado será "aprobado", de lo contrario, será "suspenso". La función debe devolver
# una tupla que contenga la media y el estado.
 
def calcular_media_estado(lista_numeros, nota_aprobado=5):
    """
    Calcula la media de una lista de números y devuelve
    una tupla con la media y el estado.
    """
    
    media = sum(lista_numeros) / len(lista_numeros)
    
    if media >= nota_aprobado:
        estado = "aprobado"
    else:
        estado = "suspenso"
    
    return (media, estado)

# %%
notas = [7, 8, 6, 9]

resultado = calcular_media_estado(notas)

print(resultado)
# Out:
# (7.5, 'aprobado')

# %%
# Ejercicio 6: Escribe una función que calcule el factorial de un número de manera recursiva.
 
def calcular_factorial(numero):
    """
    Calcula el factorial de un número
    usando recursividad.
    """
    
    if numero == 0 or numero == 1:
        return 1
    
    return numero * calcular_factorial(numero - 1)

# %%
resultado = calcular_factorial(5)

print(resultado)
# Out:
# 120

# %%
# Ejercicio 7: Genera una función que convierta una lista de tuplas a una lista de strings. Usa la función map()
 
def convertir_tuplas_a_strings(lista_tuplas):
    """
    Convierte una lista de tuplas
    en una lista de strings usando map().
    """
    
    resultado = list(map(lambda tupla: " ".join(map(str, tupla)), lista_tuplas))
    
    return resultado

# %%
tuplas = [("Hola", "mundo"), ("Python", 3)]

resultado = convertir_tuplas_a_strings(tuplas)

print(resultado)
# Out:
# ['Hola mundo', 'Python 3']

# %%
# Ejercicio 8: Escribe un programa que pida al usuario dos números e intente dividirlos. Si el usuario ingresa un valor no numérico
# o intenta dividir por cero, maneja esas excepciones de manera adecuada. Asegúrate de mostrar un mensaje
# indicando si la división fue exitosa o no.
 
def dividir_numeros():
    """
    Pide dos números al usuario e intenta dividirlos,
    manejando posibles excepciones.
    """
    
    try:
        numero1 = float(input("Introduce el primer número: "))
        numero2 = float(input("Introduce el segundo número: "))
        
        resultado = numero1 / numero2
        
        print(f"La división es: {resultado}")
        print("La división fue exitosa.")
    
    except ValueError:
        print("Error: Debes introducir valores numéricos.")
    
    except ZeroDivisionError:
        print("Error: No se puede dividir entre cero.")
    
    finally:
        print("Programa finalizado.")

# %%
dividir_numeros()
# Out:
# La división es: 0.0
# La división fue exitosa.
# Programa finalizado.

# %%
# Ejercicio 9: Escribe una función que tome una lista de nombres de mascotas como parámetro y devuelva una nueva lista
# excluyendo ciertas mascotas prohibidas en España. La lista de mascotas a excluir es ["Mapache", "Tigre",
# "Serpiente Pitón", "Cocodrilo", "Oso"].Usa la función filter()
 
def filtrar_mascotas(lista_mascotas):
    """
    Devuelve una nueva lista excluyendo
    las mascotas prohibidas usando filter().
    """
    
    mascotas_prohibidas = [
        "Mapache",
        "Tigre",
        "Serpiente Pitón",
        "Cocodrilo",
        "Oso"
    ]
    
    resultado = list(
        filter(
            lambda mascota: mascota not in mascotas_prohibidas,
            lista_mascotas
        )
    )
    
    return resultado

# %%
mascotas = ["Perro", "Gato", "Tigre", "Oso", "Canario"]

resultado = filtrar_mascotas(mascotas)

print(resultado)
# Out:
# ['Perro', 'Gato', 'Canario']

# %%
# Ejercicio 10: Escribe una función que reciba una lista de números y calcule su promedio. Si la lista está vacía, lanza una
# excepción personalizada y maneja el error adecuadamente.
 
class ListaVaciaError(Exception):
    """
    Excepción personalizada para listas vacías.
    """
    pass


def calcular_promedio(lista_numeros):
    """
    Calcula el promedio de una lista de números.
    Lanza una excepción si la lista está vacía.
    """
    
    try:
        if len(lista_numeros) == 0:
            raise ListaVaciaError("La lista está vacía.")
        
        promedio = sum(lista_numeros) / len(lista_numeros)
        
        return promedio
    
    except ListaVaciaError as error:
        print(f"Error: {error}")

# %%
numeros = [5, 7, 9]

resultado = calcular_promedio(numeros)

print(resultado)
# Out:
# 7.0

# %%
# Ejercicio 11: Escribe un programa que pida al usuario que introduzca su edad. Si el usuario ingresa un valor no numérico o un
# valor fuera del rango esperado (por ejemplo, menor que 0 o mayor que 120, maneja las excepciones
# adecuadamente.
 
def validar_edad():
    """
    Pide al usuario su edad y maneja
    posibles errores de entrada.
    """
    
    try:
        edad = int(input("Introduce tu edad: "))
        
        if edad < 0 or edad > 120:
            raise ValueError("La edad debe estar entre 0 y 120.")
        
        print(f"Edad registrada correctamente: {edad} años.")
    
    except ValueError as error:
        print(f"Error: {error}")
    
    finally:
        print("Programa finalizado.")

# %%
validar_edad()
# Out:
# Error: La edad debe estar entre 0 y 120.
# Programa finalizado.

# %%
# Ejercicio 12: Genera una función que al recibir una frase devuelva una lista con la longitud de cada palabra. Usa la función map()
 
def longitud_palabras(frase):
    """
    Devuelve una lista con la longitud
    de cada palabra usando map().
    """
    
    palabras = frase.split()
    
    resultado = list(map(len, palabras))
    
    return resultado

# %%
frase = "Estoy aprendiendo Python"

resultado = longitud_palabras(frase)

print(resultado)
# Out:
# [5, 11, 6]

# %%
# Ejercicio 13: Genera una función la cual, para un conjunto de caracteres, devuelva una lista de tuplas con cada letra en
# mayúsculas y minúsculas. Las letras no pueden estar repetidas .Usa la función map()
 
def convertir_mayusculas_minusculas(caracteres):
    """
    Recibe una lista con una palabra y devuelve una lista
    de tuplas con cada letra en mayúscula y minúscula.
    Las letras no se repiten.
    """

    palabra = caracteres[0]

    letras_unicas = list(dict.fromkeys(palabra))

    resultado = list(
        map(
            lambda letra: (letra.upper(), letra.lower()),
            letras_unicas
        )
    )

    return resultado

# %%
caracteres = ["python"]

resultado = convertir_mayusculas_minusculas(caracteres)

print(resultado)
# Out:
# [('P', 'p'), ('Y', 'y'), ('T', 't'), ('H', 'h'), ('O', 'o'), ('N', 'n')]

# %%
# Ejercicio 14: Crea una función que retorne las palabras de una lista de palabras que comience con una letra en especifico. Usa la
# función filter()
 
def filtrar_palabras_por_letra(lista_palabras, letra):
    """
    Devuelve las palabras que comienzan
    por una letra específica usando filter().
    """

    resultado = list(
        filter(
            lambda palabra: palabra.startswith(letra),
            lista_palabras
        )
    )

    return resultado

# %%
palabras = ["mesa", "manzana", "perro", "mono"]

resultado = filtrar_palabras_por_letra(palabras, "m")

print(resultado)
# Out:
# ['mesa', 'manzana', 'mono']

# %%
# Ejercicio 15: Crea una función lambda que sume 3 a cada número de una lista dada.
 
sumar_tres = lambda lista: list(map(lambda numero: numero + 3, lista))

# %%
numeros = [1, 2, 3]

resultado = sumar_tres(numeros)

print(resultado)
# Out:
# [4, 5, 6]

# %%
# Ejercicio 16: Escribe una función que tome una cadena de texto y un número entero n como parámetros y devuelva una lista de
# todas las palabras que sean más largas que n. Usa la función filter()

def palabras_mas_largas(texto, n):
    """
    Devuelve una lista con las palabras
    cuya longitud es mayor que n usando filter().
    """

    palabras = texto.split()

    resultado = list(
        filter(
            lambda palabra: len(palabra) > n,
            palabras
        )
    )

    return resultado

# %%
frase = "Python es un lenguaje muy interesante"

resultado = palabras_mas_largas(frase, 4)

print(resultado)
# Out:
# ['Python', 'lenguaje', 'interesante']

# %%
# Ejercicio 17:  Crea una función que tome una lista de dígitos y devuelva el número correspondiente. Por ejemplo, [5,7,2]
# corresponde al número quinientos setenta y dos 572. Usa la función reduce()
 
from functools import reduce


def convertir_lista_a_numero(lista_digitos):
    """
    Convierte una lista de dígitos
    en un número usando reduce().
    """

    numero = reduce(
        lambda acumulador, digito: acumulador * 10 + digito,
        lista_digitos
    )

    return numero

# %%
digitos = [5, 7, 2]

resultado = convertir_lista_a_numero(digitos)

print(resultado)
# Out:
# 572

# %%
# Ejercicio 18: Escribe un programa en Python que cree una lista de diccionarios que contenga información de estudiantes
# (nombre, edad, calificación) y use la función filter para extraer a los estudiantes con una calificación mayor o igual a
# 90. Usa la función filter()
 
def filtrar_estudiantes_destacados(lista_estudiantes):
    """
    Devuelve los estudiantes con una
    calificación mayor o igual a 90 usando filter().
    """

    resultado = list(
        filter(
            lambda estudiante: estudiante["calificacion"] >= 90,
            lista_estudiantes
        )
    )

    return resultado

# %%
estudiantes = [
        {"nombre": "Ana", "edad": 20, "calificacion": 95},
        {"nombre": "Luis", "edad": 21, "calificacion": 82},
        {"nombre": "Marta", "edad": 22, "calificacion": 90}
    ]

resultado = filtrar_estudiantes_destacados(estudiantes)

print(resultado)
# Out:
# [{'nombre': 'Ana', 'edad': 20, 'calificacion': 95}, {'nombre': 'Marta', 'edad': 22, 'calificacion': 90}]

# %%
# Ejercicio 19: Crea una función lambda que filtre los números impares de una lista dada.
 
filtrar_impares = lambda lista: list(
    filter(
        lambda numero: numero % 2 != 0,
        lista
    )
)

# %%
numeros = [1, 2, 3, 4, 5, 6]

resultado = filtrar_impares(numeros)

print(resultado)
# Out:
# [1, 3, 5]

# %%
# Ejercicio 20:  Para una lista con elementos tipo integer y string obtén una nueva lista sólo con los valores int. Usa la función
# filter()
 
def filtrar_enteros(lista):
    """
    Devuelve una nueva lista solo con
    los valores de tipo int usando filter().
    """

    resultado = list(
        filter(
            lambda elemento: isinstance(elemento, int),
            lista
        )
    )

    return resultado

# %%
datos = [1, "hola", 3, "python", 5]

resultado = filtrar_enteros(datos)

print(resultado)
# Out:
# [1, 3, 5]

# %%
# Ejercicio 21: Crea una función que calcule el cubo de un número dado mediante una función lambda
 
calcular_cubo = lambda numero: numero ** 3

# %%
resultado = calcular_cubo(3)

print(resultado)
# Out:
# 27

# %%
# Ejercicio 22: Dada una lista numérica, obtén el producto total de los valores de dicha lista. Usa la función reduce().

from functools import reduce


def calcular_producto(lista_numeros):
    """
    Calcula el producto total de los valores
    de una lista usando reduce().
    """

    producto = reduce(
        lambda acumulador, numero: acumulador * numero,
        lista_numeros
    )

    return producto

# %%
numeros = [2, 3, 4]

resultado = calcular_producto(numeros)

print(resultado)
# Out:
# 24

# %%
# Ejercicio 23: Concatena una lista de palabras. Usa la función reduce().
 
from functools import reduce


def concatenar_palabras(lista_palabras):
    """
    Concatena una lista de palabras
    usando reduce().
    """

    frase = reduce(
        lambda acumulador, palabra: acumulador + " " + palabra,
        lista_palabras
    )

    return frase

# %%
palabras = ["Hola", "mundo", "Python"]

resultado = concatenar_palabras(palabras)

print(resultado)
# Out:
# Hola mundo Python

# %%
# Ejercicio 24: Calcula la diferencia total en los valores de una lista. Usa la función reduce().
 
from functools import reduce


def calcular_diferencia_total(lista_numeros):
    """
    Calcula la diferencia total de los valores
    de una lista usando reduce().
    """

    diferencia = reduce(
        lambda acumulador, numero: acumulador - numero,
        lista_numeros
    )

    return diferencia

# %%
numeros = [100, 20, 10]

resultado = calcular_diferencia_total(numeros)

print(resultado)
# Out:
# 70

# %%
# Ejercicio 25: Crea una función que cuente el número de caracteres en una cadena de texto dada.
 
def contar_caracteres(texto):
    """
    Cuenta el número de caracteres
    de una cadena de texto.
    """

    return len(texto)

# %%
frase = "Hola mundo"

resultado = contar_caracteres(frase)

print(resultado)
# Out:
# 10

# %%
# Ejercicio 26: Crea una función lambda que calcule el resto de la división entre dos números dados.
 
calcular_resto = lambda numero1, numero2: numero1 % numero2

# %%
resultado = calcular_resto(10, 3)

print(resultado)
# Out:
# 1

# %%
# Ejercicio 27: Crea una función que calcule el promedio de una lista de números.
 
def calcular_promedio(lista_numeros):
    """
    Calcula el promedio de una lista de números.
    """

    promedio = sum(lista_numeros) / len(lista_numeros)

    return promedio

# %%
numeros = [10, 20, 30]

resultado = calcular_promedio(numeros)

print(resultado)
# Out:
# 20.0

# %%
# Ejercicio 28: Crea una función que busque y devuelva el primer elemento duplicado en una lista dada.
 
def buscar_primer_duplicado(lista):
    """
    Devuelve el primer elemento duplicado
    de una lista.
    """

    elementos_vistos = set()

    for elemento in lista:
        if elemento in elementos_vistos:
            return elemento
        
        elementos_vistos.add(elemento)

    return None

# %%
numeros = [1, 2, 3, 2, 4]

resultado = buscar_primer_duplicado(numeros)

print(resultado)
# Out:
# 2

# %%
# Ejercicio 29: Crea una función que convierta una variable en una cadena de texto y enmascare todos los caracteres con el
# carácter '#', excepto los últimos cuatro.
 
def enmascarar_texto(variable):
    """
    Convierte una variable en string y enmascara
    todos los caracteres excepto los últimos cuatro.
    """

    texto = str(variable)

    if len(texto) <= 4:
        return texto

    texto_enmascarado = "#" * (len(texto) - 4) + texto[-4:]

    return texto_enmascarado

# %%
resultado = enmascarar_texto("123456789")

print(resultado)
# Out:
# #####6789

# %%
# Ejercicio 30: Crea una función que determine si dos palabras son anagramas, es decir, si están formadas por las mismas letras
# pero en diferente orden.
 
def son_anagramas(palabra1, palabra2):
    """
    Determina si dos palabras son anagramas.
    """

    palabra1 = palabra1.lower().replace(" ", "")
    palabra2 = palabra2.lower().replace(" ", "")

    return sorted(palabra1) == sorted(palabra2)

# %%
resultado = son_anagramas("roma", "amor")

print(resultado)
# Out:
# True

# %%
# Ejercicio 31: Crea una función que solicite al usuario ingresar una lista de nombres y luego solicite un nombre para buscar en
# esa lista. Si el nombre está en la lista, se imprime un mensaje indicando que fue encontrado, de lo contrario, se
# lanza una excepción.
 
def buscar_nombre():
    """
    Solicita una lista de nombres y busca
    un nombre dentro de la lista.
    """

    try:
        nombres = input(
            "Introduce varios nombres separados por comas: "
        ).split(",")

        nombres = [nombre.strip() for nombre in nombres]

        nombre_buscar = input(
            "Introduce el nombre que deseas buscar: "
        )

        if nombre_buscar in nombres:
            print(f"{nombre_buscar} fue encontrado en la lista.")
        
        else:
            raise ValueError(
                f"{nombre_buscar} no se encuentra en la lista."
            )

    except ValueError as error:
        print(f"Error: {error}")

# %%
buscar_nombre()
# Out:
# Error: Pedro no se encuentra en la lista.

# %%
# Ejercicio 32: Crea una función que tome un nombre completo y una lista de empleados, busque el nombre completo en la lista y
# devuelve el puesto del empleado si está en la lista, de lo contrario, devuelve un mensaje indicando que la persona
# no trabaja aquí.
 
def buscar_empleado(nombre_completo, lista_empleados):
    """
    Busca un empleado en la lista y devuelve
    su puesto si existe.
    """

    for empleado in lista_empleados:

        if empleado["nombre_completo"] == nombre_completo:
            return f"{nombre_completo} trabaja como {empleado['puesto']}."

    return f"{nombre_completo} no trabaja aquí."

# %%
empleados = [
        {"nombre_completo": "Ana Garcia", "puesto": "Analista"},
        {"nombre_completo": "Luis Perez", "puesto": "Desarrollador"}
    ]

resultado = buscar_empleado("Ana Garcia", empleados)

print(resultado)
# Out:
# Ana Garcia trabaja como Analista.

# %%
# Ejercicio 33: Crea una función lambda que sume elementos correspondientes de dos listas dadas
 
sumar_listas = lambda lista1, lista2: list(
    map(
        lambda x, y: x + y,
        lista1,
        lista2
    )
)

# %%
lista_a = [1, 2, 3]
lista_b = [4, 5, 6]

resultado = sumar_listas(lista_a, lista_b)

print(resultado)
# Out:
# [5, 7, 9]

# %%
# Ejercicio 34:  Crea la clase Arbol , define un árbol genérico con un tronco y ramas como atributos. Los métodos disponibles son:
# crecer_tronco , nueva_rama , crecer_ramas , quitar_rama e info_arbol . El objetivo es implementar estos métodos para
# manipular la estructura del árbol.
# Código a seguir:

# 1. Inicializar un árbol con un tronco de longitud 1 y una lista vacía de ramas.
# 2. Implementar el método crecer_tronco para aumentar la longitud del tronco en una unidad.
# 3. Implementar el método nueva_rama para agregar una nueva rama de longitud 1 a la lista de ramas.
# 4. Implementar el método crecer_ramas para aumentar en una unidad la longitud de todas las ramas existentes.
# 5. Implementar el método quitar_rama para eliminar una rama en una posición específica.
# 6. Implementar el método info_arbol para devolver información sobre la longitud del tronco, el número de ramas y las longitudes de las mismas.

# Caso de uso:
# 1. Crear un árbol.
# 2. Hacer crecer el tronco del árbol una unidad.
# 3. Añadir una nueva rama al árbol.
# 4. Hacer crecer todas las ramas del árbol una unidad.
# 5. Añadir dos nuevas ramas al árbol.
# 6. Retirar la rama situada en la posición 2.
# 7. Obtener información sobre el árbol.
 
  
 
class Arbol:
    """
    Clase que representa un árbol con un tronco
    y una lista de ramas.
    """

    def __init__(self):
        self.tronco = 1
        self.ramas = []

    def crecer_tronco(self):
        self.tronco += 1

    def nueva_rama(self):
        self.ramas.append(1)

    def crecer_ramas(self):
        self.ramas = list(map(lambda rama: rama + 1, self.ramas))

    def quitar_rama(self, posicion):
        if posicion >= 0 and posicion < len(self.ramas):
            self.ramas.pop(posicion)
        else:
            print("La posicion indicada no existe.")

    def info_arbol(self):
        return {
            "longitud_tronco": self.tronco,
            "numero_ramas": len(self.ramas),
            "longitud_ramas": self.ramas
        }

# %%
arbol = Arbol()

arbol.crecer_tronco()

arbol.nueva_rama()

arbol.crecer_ramas()

arbol.nueva_rama()
arbol.nueva_rama()

arbol.quitar_rama(2)

resultado = arbol.info_arbol()

print(resultado)
# Out:
# {'longitud_tronco': 2, 'numero_ramas': 2, 'longitud_ramas': [2, 1]}

# %%
# Ejercicio 36: Crea la clase UsuarioBanco ,representa a un usuario de un banco con su nombre, saldo y si tiene o no cuenta
# corriente. Proporciona métodos para realizar operaciones como retirar dinero, transferir dinero desde otro usuario y
# agregar dinero al saldo.

# Código a seguir:
# 1. Inicializar un usuario con su nombre, saldo y si tiene o no cuenta corriente mediante True y False .
# 2. Implementar el método retirar_dinero para retirar dinero del saldo del usuario. Lanzará un error en caso de no
#    poder hacerse.
# 3. Implementar el método transferir_dinero para realizar una transferencia desde otro usuario al usuario actual.
#    Lanzará un error en caso de no poder hacerse.
# 4. Implementar el método agregar_dinero para agregar dinero al saldo del usuario.

# Caso de uso:
# 1. Crear dos usuarios: "Alicia" con saldo inicial de 100 y "Bob" con saldo inicial de 50, ambos con cuenta corriente.
# 2. Agregar 20 unidades de saldo de "Bob".
# 3. Hacer una transferencia de 80 unidades desde "Bob" a "Alicia".
# 4. Retirar 50 unidades de saldo a "Alicia".
 
 
class UsuarioBanco:
    """
    Representa a un usuario de un banco.
    """

    def __init__(self, nombre, saldo, cuenta_corriente):
        self.nombre = nombre
        self.saldo = saldo
        self.cuenta_corriente = cuenta_corriente

    def retirar_dinero(self, cantidad):
        """
        Retira dinero del saldo del usuario.
        """

        if not self.cuenta_corriente:
            raise ValueError(
                "El usuario no tiene cuenta corriente."
            )

        if cantidad <= 0:
            raise ValueError(
                "La cantidad debe ser mayor que cero."
            )

        if cantidad > self.saldo:
            raise ValueError(
                "Saldo insuficiente."
            )

        self.saldo -= cantidad

    def transferir_dinero(self, otro_usuario, cantidad):
        """
        Transfiere dinero desde otro usuario
        al usuario actual.
        """

        if not self.cuenta_corriente or not otro_usuario.cuenta_corriente:
            raise ValueError(
                "Ambos usuarios deben tener cuenta corriente."
            )

        otro_usuario.retirar_dinero(cantidad)

        self.saldo += cantidad

    def agregar_dinero(self, cantidad):
        """
        Agrega dinero al saldo del usuario.
        """

        if cantidad <= 0:
            raise ValueError(
                "La cantidad debe ser mayor que cero."
            )

        self.saldo += cantidad

    def mostrar_info(self):
        """
        Devuelve la informacion del usuario.
        """

        return {
            "nombre": self.nombre,
            "saldo": self.saldo,
            "cuenta_corriente": self.cuenta_corriente
        }

# %%
# Crear usuarios
alicia = UsuarioBanco("Alicia", 100, True)
bob = UsuarioBanco("Bob", 50, True)

# Agregar dinero a Bob
bob.agregar_dinero(20)

# Intentar transferencia
try:
    alicia.transferir_dinero(bob, 80)

except ValueError as error:
    print(
        f"No se pudo transferir 80 desde "
        f"{bob.nombre} a {alicia.nombre}: {error}"
    )

# Retirar dinero a Alicia
alicia.retirar_dinero(50)

# Mostrar informacion final
print(alicia.mostrar_info())
print(bob.mostrar_info())
# Out:
# No se pudo transferir 80 desde Bob a Alicia: Saldo insuficiente.
# {'nombre': 'Alicia', 'saldo': 50, 'cuenta_corriente': True}
# {'nombre': 'Bob', 'saldo': 70, 'cuenta_corriente': True}

# %%
# Ejercicio 37. Crea una función llamada procesar_texto que procesa un texto según la opción especificada: contar_palabras ,
# reemplazar_palabras , eliminar_palabra . Estas opciones son otras funciones que tenemos que definir primero y llamar dentro
# de la función procesar_texto .

# Código a seguir:
# 1. Crear una función contar_palabras para contar el número de veces que aparece cada palabra en el texto. Tiene
#    que devolver un diccionario.
# 2. Crear una función reemplazar_palabras para remplazar una palabra_original del texto por una palabra_nueva . Tiene
#    que devolver el texto con el remplazo de palabras.
# 3. Crear una función eliminar_palabra para eliminar una palabra del texto. Tiene que devolver el texto con la palabra
#    eliminada.
# 4.Crear la función procesar_texto que tome un texto, una opción(entre "contar", "reemplazar", "eliminar") y un
# número de argumentos variable según la opción indicada.

# Caso de uso:
# Comprueba el funcionamiento completo de la función procesar_texto
 
def contar_palabras(texto):
    """Cuenta cuantas veces aparece cada palabra en un texto."""
    palabras = texto.lower().split()
    conteo = {}

    for palabra in palabras:
        conteo[palabra] = conteo.get(palabra, 0) + 1

    return conteo


def reemplazar_palabras(texto, palabra_original, palabra_nueva):
    """Reemplaza una palabra por otra."""
    return texto.replace(palabra_original, palabra_nueva)


def eliminar_palabra(texto, palabra_eliminar):
    """Elimina una palabra del texto."""
    palabras = texto.split()
    palabras_filtradas = [palabra for palabra in palabras if palabra != palabra_eliminar]
    return " ".join(palabras_filtradas)


def procesar_texto(texto, opcion, *args):
    """Procesa un texto segun la opcion indicada."""
    if opcion == "contar":
        return contar_palabras(texto)

    if opcion == "reemplazar":
        if len(args) != 2:
            raise ValueError("Para reemplazar debes indicar palabra_original y palabra_nueva.")
        return reemplazar_palabras(texto, args[0], args[1])

    if opcion == "eliminar":
        if len(args) != 1:
            raise ValueError("Para eliminar debes indicar una palabra.")
        return eliminar_palabra(texto, args[0])

    raise ValueError("Opcion no valida. Usa contar, reemplazar o eliminar.")

# %%
texto = "python es facil python es util"

print(procesar_texto(texto, "contar"))

print(
    procesar_texto(
        texto,
        "reemplazar",
        "python",
        "SQL"
    )
)

print(
    procesar_texto(
        texto,
        "eliminar",
        "es"
    )
)
# Out:
# {'python': 2, 'es': 2, 'facil': 1, 'util': 1}
# SQL es facil SQL es util
# python facil python util

# %%
# Ejercicio 38: Genera un programa que nos diga si es de noche, de día o tarde según la hora proporcionada por el usuario.
 
def momento_del_dia():
    """
    Indica si es de dia, tarde o noche
    segun la hora introducida.
    """

    try:
        hora = int(input("Introduce una hora (0-23): "))

        if hora < 0 or hora > 23:
            raise ValueError(
                "La hora debe estar entre 0 y 23."
            )

        if 6 <= hora < 12:
            print("Es de dia.")

        elif 12 <= hora < 20:
            print("Es de tarde.")

        else:
            print("Es de noche.")

    except ValueError as error:
        print(f"Error: {error}")

# %%
momento_del_dia()
# Out:
# Es de dia.

# %%
# Ejercicio 39: Escribe un programa que determine qué calificación en texto tiene un alumno en base a su calificación numérica.
# Las reglas de calificación son:
# - 0 a 69 insuficiente
# - 70 a 79 bien
# - 80 a 89 muy bien
# - 90 a100 excelente
 
def calificacion_texto():
    """
    Determina la calificacion en texto
    segun la nota numerica del alumno.
    """

    try:
        nota = int(input("Introduce la calificacion (0-100): "))

        if nota < 0 or nota > 100:
            raise ValueError(
                "La calificacion debe estar entre 0 y 100."
            )

        if 0 <= nota <= 69:
            print("Insuficiente")

        elif 70 <= nota <= 79:
            print("Bien")

        elif 80 <= nota <= 89:
            print("Muy bien")

        else:
            print("Excelente")

    except ValueError as error:
        print(f"Error: {error}")

# %%
calificacion_texto()
# Out:
# Excelente

# %%
# Ejercicio 40. Escribe una función que tome dos parámetros: figura (una cadena que puede ser "rectangulo" , "circulo" o
# "triangulo" ) y datos (una tupla con los datos necesarios para calcular el área de la figura).
 
import math


def calcular_area(figura, datos):
    """
    Calcula el area de una figura geometrica.
    """

    if figura == "rectangulo":

        base, altura = datos

        return base * altura

    elif figura == "circulo":

        radio = datos[0]

        return math.pi * (radio ** 2)

    elif figura == "triangulo":

        base, altura = datos

        return (base * altura) / 2

    else:
        raise ValueError(
            "Figura no valida. Usa rectangulo, circulo o triangulo."
        )

# %%
# Rectangulo
print(calcular_area("rectangulo", (5, 3)))

# Circulo
print(round(calcular_area("circulo", (4,)), 2))

# Triangulo
print(calcular_area("triangulo", (6, 2)))
# Out:
# 15
# 50.27
# 6.0

# %%
# Ejercicio 41.  En este ejercicio, se te pedirá que escribas un programa en Python que utilice condicionales para determinar el
# monto final de una compra en una tienda en línea, después de aplicar un descuento. El programa debe hacer lo
# siguiente:
# 1. Solicita al usuario que ingrese el precio original de un artículo.
# 2. Pregunta al usuario si tiene un cupón de descuento (respuesta sí o no).
# 3. Si el usuario responde que sí, solicita que ingrese el valor del cupón de descuento.
# 4. Aplica el descuento al precio original del artículo, siempre y cuando el valor del cupón sea válido (es decir, mayor
#    a cero). Por ejemplo, descuento de 15€.
# 5. Muestra el precio final de la compra, teniendo en cuenta el descuento aplicado o sin él.
# 6. Recuerda utilizar estructuras de control de flujo como if, elif y else para llevar a cabo estas acciones en tu
#    programa de Python.
 
def calcular_precio_final():
    """
    Calcula el precio final de una compra
    aplicando un cupon de descuento.
    """

    try:
        precio_original = float(
            input("Introduce el precio del articulo: ")
        )

        if precio_original <= 0:
            raise ValueError(
                "El precio debe ser mayor que cero."
            )

        tiene_cupon = input(
            "¿Tienes cupon de descuento? (si/no): "
        ).lower()

        precio_final = precio_original

        if tiene_cupon == "si":

            descuento = float(
                input(
                    "Introduce el valor del descuento: "
                )
            )

            if descuento <= 0:
                raise ValueError(
                    "El descuento debe ser mayor que cero."
                )

            if descuento > precio_original:
                raise ValueError(
                    "El descuento no puede ser mayor que el precio."
                )

            precio_final -= descuento

            print(
                f"Descuento aplicado: {descuento}€"
            )

        elif tiene_cupon == "no":

            print("No se aplico ningun descuento.")

        else:
            raise ValueError(
                "Debes responder si o no."
            )

        print(
            f"El precio final es: {precio_final}€"
        )

    except ValueError as error:
        print(f"Error: {error}")

# %%
calcular_precio_final()
# Out:
# Descuento aplicado: 15.0€
# El precio final es: 85.0€
